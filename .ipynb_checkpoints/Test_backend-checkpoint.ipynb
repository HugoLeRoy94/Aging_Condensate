# %%
import numpy as np
from System_backend import *
import matplotlib.pyplot as plt
import ellipse as ell
import tqdm
# %matplotlib widget
plt.rcParams["figure.figsize"] = (4,3)

# %%
ell_tot = 200.
distance_anchor = 100.
rho0 = 0.01
temperature = 1.
tau_0 = np.exp(1/temperature)
print(r'$\tau_0 = $'+str(tau_0))
# Out:
# $\tau_0 = $2.718281828459045

# %%
plt.close()
S = System(ell_tot,distance_anchor,rho0,temperature)
S.Plot3DSystem()
# Out:
# (<Figure size 400x300 with 1 Axes>, <Axes3DSubplot:xlabel='x', ylabel='y'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
time_tot = 10000
Ells = np.zeros(time_tot,dtype=float)
Ns = np.zeros(time_tot,dtype=float)
time_bind = list()
time_ub = list()
time = np.zeros(time_tot,dtype=float)
for t in tqdm.tqdm(range(time_tot)):
    bind, dt = S.evolve()
    for n,ell in enumerate(S.get_ell()):
        if ell<np.linalg.norm(S.get_R()[n+1]-S.get_R()[n]):
            print(bind)
            print(S.get_ell())
            print(S.get_R())
            for n,ell in enumerate(S.get_ell()):
                print(np.linalg.norm(S.get_R()[n+1]-S.get_R()[n]))
            raise SystemExit('error in code want to exit')
    R = S.get_R()       
    r = S.get_r()
    if bind :
        time_bind.append(dt)
    else:
        time_ub.append(dt)
    if t!=0:
        time[t]= time[t-1]+dt
    else:
        time[t] = dt
    Ells[t] = np.mean(S.get_ell())
    Ns[t] = S.get_N_loop()
# Out:
#  10%|██████████████████████▉                                                                                                                                                                                                                  | 982/10000 [00:01<00:15, 586.05it/s]
# True
# [ 47.8085237 152.1914763]
# [[  0.           0.           0.        ]
#  [ 47.43668309   5.02122605  -3.84862127]
#  [100.           0.           0.        ]]
# 100.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 7>()
#      13         print(S.get_R())
#      14         for n,ell in enumerate(S.get_ell()):
# ---> 15             print(np.linalg.norm(R[n+1]-R[n]))
#      16         raise SystemExit('error in code want to exit')
#      17 R = S.get_R()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
r
# Out:
# array([[ 5.08759785e+01, -2.51457079e+00,  6.26310276e+00],
#        [ 2.17701315e+01,  7.65710552e-01, -4.52159731e+00],
#        [ 4.37380460e+01, -4.92059853e+00,  6.48274105e-02],
#        [ 4.11805670e+01, -2.74048614e+00,  6.06415602e+00],
#        [ 3.56889599e+01,  6.22424510e+00,  2.32773464e+00],
#        [ 6.61156783e+01, -5.41137475e+00,  1.73449621e+00],
#        [ 2.70492411e+01, -3.31042017e-01,  1.19756980e+00],
#        [ 7.26055737e+01, -1.33205164e+00, -5.63744381e+00],
#        [ 7.03193774e+01,  6.32616540e+00,  7.90180605e-01],
#        [ 4.93818359e+01,  1.15395162e+00,  3.22255546e+00],
#        [ 2.46849624e+01, -2.39917798e+00,  4.52516504e+00],
#        [ 7.12915709e+01,  6.99391983e-01,  2.63027778e+00],
#        [ 4.74366831e+01,  5.02122605e+00, -3.84862127e+00],
#        [ 4.43329321e+01, -5.51669395e+00,  3.80873408e+00],
#        [ 6.27244297e+01, -5.55285874e-01, -2.87901110e-01],
#        [ 5.69095903e+01,  1.10439205e+00, -3.70644770e+00],
#        [ 4.56818209e+01,  1.40038896e+00, -6.44405174e+00],
#        [ 4.21210163e+01, -6.04298247e+00,  3.14180375e+00],
#        [ 4.61709308e+01,  1.34087736e-01,  1.56823359e+00],
#        [ 3.48656492e+01,  2.92265798e-01,  5.21910544e+00],
#        [ 3.00831023e+01, -3.47291698e+00,  4.32275942e+00],
#        [ 6.95342792e+01,  1.04508245e+00,  4.34022486e+00],
#        [ 5.29949739e+01,  1.00857388e+00, -3.72066822e+00],
#        [ 6.82262596e+01,  1.59349817e+00, -6.15808834e+00],
#        [ 2.91021807e+01, -1.82209958e+00, -1.37053449e+00],
#        [ 2.56742394e+01, -3.01252104e+00, -3.22523558e+00]])

# %%
S.Plot3DSystem()
# Out:
# (<Figure size 400x300 with 1 Axes>, <Axes3DSubplot:xlabel='x', ylabel='y'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(S.get_ell())
print(S.get_R())
# Out:
# [ 18.  25. 157.]
# [[  0.           0.           0.        ]
#  [ 94.06492851   0.20683532   4.42576611]
#  [ 99.42894392   2.74776709  -1.52466526]
#  [100.           0.           0.        ]]

# %%
plt.close()
plt.hist(Ns)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
fig,ax = plt.subplots()
plt.plot(np.arange(0,time_tot,1),time/tau_0)
#plt.hist(time_bind,bins=100)
#plt.yscale('log')
#plt.xscale('log')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
S.Plot3DSystem()
# Out:
# (<Figure size 400x300 with 1 Axes>, <Axes3DSubplot:xlabel='x', ylabel='y'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
S.Print_loop_positions()
# Out:
# theta Phi -3.10553 -2.1811
# xg,yg,zg 1605.24 -18.9248 43.7862
# volume 2040.52
# ell 75
# anchoring points. left :1607.17 -18.855 41.0194 right : 1603.3 -18.9946 46.553
# number of crosslinkers of this loop :25
#
# theta Phi 2.99025 -3.56199
# xg,yg,zg 1605.42 -21.3222 38.5712
# volume 33.7915
# ell 21
# anchoring points. left :1606.81 -21.5341 39.1923 right : 1604.03 -21.1103 37.9501
# number of crosslinkers of this loop :2
#
# theta Phi -0.323925 0.663469
# xg,yg,zg 1604.39 -19.3596 45.7031
# volume 34.3831
# ell 23
# anchoring points. left :1603.3 -18.9946 46.553 right : 1605.47 -19.7247 44.8532
# number of crosslinkers of this loop :0
#
# theta Phi -0.151347 -0.4204
# xg,yg,zg 1605.42 -21.3222 38.5712
# volume 1570.94
# ell 63
# anchoring points. left :1604.03 -21.1103 37.9501 right : 1606.81 -21.5341 39.1923
# number of crosslinkers of this loop :16
#
# theta Phi 1.34664 0.418084
# xg,yg,zg 1606.41 -22.2073 41.3589
# volume 65.1266
# ell 18
# anchoring points. left :1605.64 -25.5596 41.6985 right : 1607.17 -18.855 41.0194
# number of crosslinkers of this loop :2

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlim(0,50)
ax.set_ylim(-25,25)
ax.set_zlim(-25,25)
ax.scatter(R[:,0],R[:,1],R[:,2])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
