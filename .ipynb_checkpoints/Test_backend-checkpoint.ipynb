# %%
import numpy as np
from System_backend import *
import matplotlib.pyplot as plt
import ellipse as ell
# %matplotlib widget

# %%
ell_tot = 100.
distance_anchor = 50.
rho0 = 0.11
temperature = 0.1

# %%
S = System(ell_tot,distance_anchor,rho0,temperature)
r = S.get_r()
print(r.shape)
R = S.get_R()

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

Ell = S.get_ell()
for i in range(0,R.shape[0]-1):
    axes = ell.construct_axes_from_main_axe((R[i+1]-R[i])/2,np.sqrt(Ell[i]))
    xel,yel,zel = ell.ellipse(axes,[0.5*(R[i,0]+R[i+1,0]),0.5*(R[i+1,1]+R[i,1]),(R[i+1,2]+R[i,2])*0.5])
    ax.plot_wireframe(xel, yel, zel,  rstride=4, cstride=4, color='#2980b9', alpha=0.2)

#ax.set_xlim(0,50)
#ax.set_ylim(-25,25)
#ax.set_zlim(-25,25)

#ax.scatter(r[:,0],r[:,1],r[:,2])
# Out:
# (274, 3)
# [[5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]
#  [5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]
#  [5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]
#  ...
#  [5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]
#  [5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]
#  [5.00000000e+01 4.99874136e+01 4.99496669e+01 ... 5.03330882e-02
#   1.25864404e-02 0.00000000e+00]]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
R
# Out:
# array([[ 0.,  0.,  0.],
#        [50.,  0.,  0.]])

# %%
print(S.evolve())
r = S.get_r()
print(r.shape)
R = S.get_R()
print(R)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlim(0,50)
ax.set_ylim(-25,25)
ax.set_zlim(-25,25)

ax.scatter(r[:,0],r[:,1],r[:,2])
ax.scatter(R[:,0],R[:,1],R[:,2],s=50)
# Out:
# 35.093 12.0565
# 288462.24328291795
# (77, 3)
# [[50.          0.          0.        ]
#  [11.68678622  2.49410996 -1.59948356]
#  [37.37331758  1.89500018 -2.64303931]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
S.Print_loop_positions()
# Out:
# theta Phi 0.0506612 0.0706024
# xg,yg,zg 18.6867 0.9475 -1.32152
# volume 1246.4
# ell 63.454
# anchoring points. left :0 0 0 right : 37.3733 1.895 -2.64304
# number of crosslinkers of this loop :127
#
# theta Phi -0.148967 -0.206343
# xg,yg,zg 43.6867 0.9475 -1.32152
# volume 249.503
# ell 36.546
# anchoring points. left :37.3733 1.895 -2.64304 right : 50 0 0
# number of crosslinkers of this loop :22

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_xlim(0,50)
ax.set_ylim(-25,25)
ax.set_zlim(-25,25)
ax.scatter(R[:,0],R[:,1],R[:,2])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
