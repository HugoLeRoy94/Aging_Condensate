# %%
import numpy as np
from System_backend import *
import matplotlib.pyplot as plt
import ellipse as ell
import tqdm
from multiprocessing import Pool
#%matplotlib widget
#%matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (4,3)

# %%
R = 50
L = 100
Eb = -10.
kdiff = 5.20142e-05#0.0605704#np.exp(Eb)/2
size = 10
dangling = True
S = System(ell_tot=L,rho0=0.1,BindingEnergy=Eb,kdiff=kdiff,seed = 5984365,Nlinker=3)
size =100
step_tot = 10**7
dt = np.zeros(step_tot,dtype=float)
move = np.zeros(4,dtype=float)
# Out:
# counter : 1
# N_linker_max :3
# 2

# %%
S.reset_crosslinkers()
# Out:
# counter : 3
# N_linker_max :3
# 0
# destroy
# destroy
# destroy

# %%
S.get_r().shape
# Out:
# (3, 3)

# %%
S.Plot3DSystem()
# Out:
# (<Figure size 288x216 with 1 Axes>, <Axes3DSubplot:xlabel='x', ylabel='y'>)

# %%
S.evolve()
# Out:
# (3, 3699.374626145236)

# %%
for i in range(step_tot):
    movetype,Dt = S.evolve()
    if np.isnan(Dt):
        raise ValueError
    dt[i] = Dt
    move[movetype] +=1            
time = np.cumsum(dt)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 for i in range(step_tot):
# ----> 2     movetype,Dt = S.evolve()
#       3     if np.isnan(Dt):
#       4         raise ValueError
#
# File ~/PostDoc/aging_condensates/Simulation/Gillespie/System_backend/System_backend.py:77, in System.evolve(self, steps)
#      75 else:
#      76     bind = c_int(0)
# ---> 77     time = lib.evolve(self.Address,byref(bind))
#      78     return bind.value, time
#
# KeyboardInterrupt:

# %%
move
# Out:
# array([9.999898e+06, 1.010000e+02, 0.000000e+00, 1.000000e+00])

# %%
S = System(ell_tot,rho0,BindingEnergy,kdiff=np.exp(BindingEnergy*0.9),seed=19880,sliding=True)
steptot = 10**6
R = list()#np.zeros((steptot,3),dtype=float)
t = list()
moves = np.zeros(4,dtype=float)
for step in range(steptot):
    #print(step)
    bind,time = S.evolve(steps=1)
    moves[bind]+=1
    #if S.get_N_loop()>1:
    #R[step] = S.get_r()[1]
    if t.__len__() == 0:
        t.append(time)
    else :
        t.append(time+t[-1])    
    R.append(S.get_r()[np.argwhere(S.get_r()[:,0]!=0.)[0,0]])
    #print("bind : "+str(bind))
t = np.array(t)*np.exp(BindingEnergy)
R = np.array(R)
moves = moves/sum(moves)
# Out:
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset
# reset

# %%
moves
# Out:
# array([0.491418, 0.017163, 0.      , 0.491419])

# %%
#%matplotlib notebook
#plt.plot(t[50000:],R[50000:,0])
#plt.plot(t,R[:,0])
#plt.plot(t,R[:,1])
#plt.plot(t,R[:,2])
plt.plot(t,np.array([np.linalg.norm(r) for r in R]))
#plt.xlim(20500,21000)

# %%
mean_dist = 0.
for i in range(steptot-1):
    mean_dist += np.linalg.norm(R[i])*(t[i+1]-t[i])/steptot
print(mean_dist)
#np.sum(np.array([np.linalg.norm(r) for r in R])*(t[i])/(steptot)
# Out:
# 15.630885940055336

# %%
S.Plot3DSystem()
# Out:
# (<Figure size 288x216 with 1 Axes>, <Axes3DSubplot:xlabel='x', ylabel='y'>)

# %%
plt.hist(bind)
plt.xticks([0,1,2,3],['unbind','diffuse_linker','slide','bind'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f598733e1f0>,
#   <matplotlib.axis.XTick at 0x7f598733e220>,
#   <matplotlib.axis.XTick at 0x7f5987348b20>,
#   <matplotlib.axis.XTick at 0x7f59873180a0>],
#  [Text(0, 0, 'unbind'),
#   Text(1, 0, 'diffuse_linker'),
#   Text(2, 0, 'slide'),
#   Text(3, 0, 'bind')])

# %%
S.get_ell_coordinates()
# Out:
# array([ 0., 44., 51., 94.])

# %%
S.get_ell_coordinates()
# Out:
# array([ 0.,  7., 11., 14., 17., 21., 26., 29., 46., 50., 57., 68., 78.,
#        82., 89., 95., 99.])

# %%
S.reset_crosslinkers()

# %%
def get_av_F(BindingEnergy,rho0):
    teq = 10000
    ell_tot = 1000.
    #rho0 = 1/9
    F,Nloop,time = np.zeros(teq,dtype=float),np.zeros(teq,dtype=float),np.zeros(teq,dtype=float)
    S = System(ell_tot,rho0,BindingEnergy,seed=19880)
    for t in range(teq):
        F[t] = S.get_F()
        Nloop[t] = S.get_N_loop()
        bind,time[t] = S.evolve()
    return (F,Nloop,time)

# %%
fres = list()
for d in np.linspace(5,15,10):
    rho0 = 1/d        
    BindingEnergies = np.linspace(0.,-10,10)
    with Pool(10) as p:
        res = p.map(get_av_F,zip(BindingEnergies,np.array([rho0 for _ in range(BindingEnergies.shape[0])])))
    fres.apend(np.array(res))
fres = np.array(fres)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/hcleroy/anaconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/hcleroy/anaconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# TypeError: get_av_F() missing 1 required positional argument: 'rho0'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a>     BindingEnergies = np.linspace(0.,-10,10)
#       <a href='vscode-notebook-cell:/home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>     with Pool(10) as p:
# ----> <a href='vscode-notebook-cell:/home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a>         res = p.map(get_av_F,zip(BindingEnergies,np.array([rho0 for _ in range(BindingEnergies.shape[0])])))
#       <a href='vscode-notebook-cell:/home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a>     fres.apend(np.array(res))
#       <a href='vscode-notebook-cell:/home/hcleroy/PostDoc/Simulation/Aging_Condensates/System_backend/Test_backend.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a> fres = np.array(fres)
#
# File ~/anaconda3/lib/python3.8/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/lib/python3.8/multiprocessing/pool.py:771, in ApplyResult.get(self, timeout)
#     769     return self._value
#     770 else:
# --> 771     raise self._value
#
# TypeError: get_av_F() missing 1 required positional argument: 'rho0'

# %%
avF = list()
for Flooptime in res:
    avF.append(np.sum(Flooptime[0]*Flooptime[2])/np.sum(Flooptime[2]))

# %%
avF
# Out:
# [-2492.4173493462913,
#  -2411.2401307466516,
#  -2164.34902984414,
#  -1476.4816115702497,
#  -684.7480325649668,
#  -405.9096596268204,
#  -299.8710575751285,
#  -285.4055930287794,
#  -301.7184166152068,
#  -292.48173387555937]

# %%
avF2 = avF

# %%
plt.plot(BindingEnergies,avF)
plt.plot(BindingEnergies,avF2)

# %%
fig,ax = plt.subplots(ncols = 2,figsize=(12,10))
ax[0].plot(np.cumsum(time),F)
ax[1].plot(np.cumsum(time),Nloop)

# %%
print(np.sum(F*time)/np.sum(time))
# Out:
# -2523.0635150441876

# %%
print(S.get_r_size())
print(S.get_r_system_size())
for t in range(1000):
    if t%100 == 0:
        print(t)
    S.evolve()
# Out:
# 183
# 183
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
# Out:
# (False, 1100.0281168918725)

# %%
print(S.get_r().shape)
S.get_R().shape
# Out:
# (61, 3)
# (6, 3)

# %%
fig,ax = plt.subplots(ncols=3,figsize=(15,5))
ax[0].scatter(S.get_r()[:,1],S.get_r()[:,2])
ax[0].scatter(S.get_R()[:,1],S.get_R()[:,2],s=60)

ax[1].scatter(S.get_r()[:,0],S.get_r()[:,1])
ax[1].scatter(S.get_R()[:,0],S.get_R()[:,1],s=60)

ax[2].scatter(S.get_r()[:,0],S.get_r()[:,2])
ax[2].scatter(S.get_R()[:,0],S.get_R()[:,2],s=60)

# %%
S.reset_crosslinkers()

# %%
fig,ax = plt.subplots(ncols=3,figsize=(15,5))
ax[0].scatter(S.get_r()[:,1],S.get_r()[:,2])
ax[0].scatter(S.get_R()[:,1],S.get_R()[:,2],s=60)

ax[1].scatter(S.get_r()[:,0],S.get_r()[:,1])
ax[1].scatter(S.get_R()[:,0],S.get_R()[:,1],s=60)

ax[2].scatter(S.get_r()[:,0],S.get_r()[:,2])
ax[2].scatter(S.get_R()[:,0],S.get_R()[:,2],s=60)

# %%
plt.scatter(S.get_ell_coordinates(),np.array([1 for _ in range(S.get_N_loop())]))

# %%
N = list()
rsize = list()
Ell = list()
F = list()
for i in range(1000):
    S.evolve()
    N.append(S.get_N_loop())
    rsize.append(S.get_r().shape[0])
    Ell.append(sum(S.get_ell()))
    F.append(S.get_F())
N = np.array(N)
rsize=np.array(rsize)
Ell= np.array(Ell)
F = np.array(F)

# %%
plt.close()
#plt.scatter(np.arange(0,N.shape[0],1),N)
#plt.scatter(np.arange(0,rsize.shape[0],1),rsize)
#plt.scatter(np.arange(0,Ell.shape[0],1),Ell)
plt.scatter(np.arange(0,F.shape[0],1),F)

# %%
plt.close()
fig,ax = S.Plot3DSystem()
#plt.close()

# %%
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
print(S.get_ell())
print(S.get_R())
# Out:
# [642.]
# [[  0.           0.           0.        ]
#  [-16.097395   -26.77912392  -2.05946978]]

# %%
time_tot = 10000
Ells = np.zeros(time_tot,dtype=float)
Ns = np.zeros(time_tot,dtype=float)
time_bind = list()
time_ub = list()
time = np.zeros(time_tot,dtype=float)
for t in tqdm.tqdm(range(time_tot)):
    bind, dt = S.evolve()
#    for n,ell in enumerate(S.get_ell()):
#        if ell<np.linalg.norm(S.get_R()[n+1]-S.get_R()[n]):
#            print(bind)
#            print(S.get_ell())
#            print(S.get_R())
#            for n,ell in enumerate(S.get_ell()):
#                print(np.linalg.norm(S.get_R()[n+1]-S.get_R()[n]))
#            raise SystemExit('error in code want to exit')
    R = S.get_R()       
    r = S.get_r()
    if bind :
        time_bind.append(dt)
    else:
        time_ub.append(dt)
    if t!=0:
        time[t]= time[t-1]+dt
    else:
        time[t] = dt
    Ells[t] = np.mean(S.get_ell())
    Ns[t] = S.get_N_loop()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 11577.02it/s]

# %%
plt.close()
fig,ax = S.Plot3DSystem()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
plt.hist(Ns)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
fig,ax = plt.subplots()
#lt.plot(np.arange(0,time_tot,1),time/tau_0)
plt.plot(np.arange(0,time_tot,1),Ns)
#plt.hist(time_bind,bins=100)
#plt.yscale('log')
#plt.xscale('log')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
S.get_ell()
# Out:
# array([ 77., 179.,  77.,  46.,  40., 116.,  83.,  32.,  49., 104.,  87.,
#        120.,  27.,  23.,  45.,  98.,  68., 171., 146., 284., 128.])
